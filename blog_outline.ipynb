# %% [markdown]
# ## Tips and tricks

# %% [markdown]
# ### Filter before merge

# %%
import pandas as pd
import numpy as np
reviews = pd.read_csv('data/reviews.csv')
reviews_summary = pd.read_csv('data/reviews_summary.csv')

# %%
listings = pd.read_csv('data/listings.csv')

# %%
listings = listings.rename(columns={'id':'listing_id'})

# %%
listings = listings.sample(frac=0.2, random_state=1337)

# %%
# %%timeit
listings.merge(reviews_summary, on='listing_id')
# Out:
# 86.6 ms ± 805 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
reviews_subset = reviews_summary[reviews_summary['listing_id'].isin(listings['listing_id'])]
listings.merge(reviews_subset, on='listing_id')
# Out:
# 48.7 ms ± 618 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## Vectorize operations

# %% [markdown]
# ### Normalize prize between 0 and 1

# %%
listings.loc[listings['price']==0, 'price'] = 30

# %%
# Iterative
min_prize = listings['price'].min()
max_prize = listings['price'].max()

# %%
max_prize, min_prize
# Out:
# (8600, 9)

# %%
# %%timeit
norm_prizes = np.zeros(len(listings,))
for i in range(len(listings)):
    norm_prizes[i] = (listings.iloc[i]['price'] - min_prize) / (max_prize - min_prize)
listings['norm_price'] = norm_prizes
# Out:
# 1.08 s ± 13.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit 
listings['norm_price'] = listings['price'].map(lambda x: (x - min_prize) / (max_prize - min_prize))
# Out:
# 3.85 ms ± 12.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
listings['norm_price'] = (listings['price'] - min_prize) / (max_prize - min_prize)
# Out:
# 565 µs ± 6.04 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ## Normalize price per neighbourhood group

# %%
grouped_prices_max = listings.groupby('neighbourhood_group', as_index=False).max()
grouped_prices_max = grouped_prices_max.rename(columns={'price':'max_price'})[['neighbourhood_group', 'max_price']]

# %%
grouped_prices_min = listings.groupby('neighbourhood_group', as_index=False).min()
grouped_prices_min = grouped_prices_min.rename(columns={'price':'min_price'})[['neighbourhood_group', 'min_price']]

# %%
listings_groups = listings.merge(grouped_prices_max, on='neighbourhood_group')
listings_groups = listings_groups.merge(grouped_prices_min, on='neighbourhood_group')

# %%
listings_groups['norm_price'] = (listings_groups['price'] - listings_groups['min_price']) / (listings_groups['max_price'] - listings_groups['min_price'])

# %% [markdown]
# ## using numpy

# %% [markdown]
# Lets say we want to do more advanced calculations for a subset of our data, then it can be faster to convert the data to numpy arrays and loop through them.

# %%
room_type_scores = {'Entire home/apt': 1,
                   'Private room': 0.7,
                   'Shared room': 0.2}

# %%
# %%timeit
prizes = listings['price'].values
nr_reviews = listings['number_of_reviews'].values
availability = listings['availability_365'].values
minimum_nights = listings['minimum_nights'].values
room_types = listings['room_type'].values
scores = np.zeros(len(prizes))
for i in range(len(prizes)):
    if availability[i] == 0:
        scores[i] = 0
    elif prizes[i] > 100:
        scores[i] = 0
    elif minimum_nights[i] > 3:
        scores[i] = 0
    elif nr_reviews[i] < 10:
        scores[i] = 0
    else:
        room_type_score = room_type_scores[room_types[i]]
        prize_score = (100 - prizes[i]) / 100
        review_score = 1 if nr_reviews[i] > 50 else 0.5
        scores[i] = room_type_score * prize_score * review_score
listings['score'] = scores
# Out:
# 6.11 ms ± 79.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
scores = np.zeros(len(prizes))
for i in range(len(prizes)):
    row = listings.iloc[i]
    if row['availability_365'] == 0:
        scores[i] = 0
    elif row['price'] > 100:
        scores[i] = 0
    elif row['minimum_nights'] > 3:
        scores[i] = 0
    elif row['number_of_reviews'] < 10:
        scores[i] = 0
    else:
        room_type_score = room_type_scores[row['room_type']]
        prize_score = (100 - row['price']) / 100
        review_score = 1 if row['number_of_reviews'] > 50 else 0.5
        scores[i] = room_type_score * prize_score * review_score
listings['score'] = scores
# Out:
# 1.19 s ± 18.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit 
listings['room_type_score'] = listings['room_type'].map(lambda x: room_type_scores[x])
listings['prize_score'] = (100 - listings['price']) / 100
listings['review_score'] = listings['number_of_reviews'].map(lambda x: 1 if x > 50 else 0.5)
listings['score'] = listings['room_type_score'] * listings['prize_score'] * listings['review_score']
listings.loc[(listings['availability_365'] == 0) | (listings['price'] > 100) | (listings['minimum_nights'] > 3) | (listings['number_of_reviews'] < 10), 'score'] = 0
# Out:
# 9.11 ms ± 84.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
def room_score(availability, price, min_nights, nr_reviews, room_type):
    if availability== 0:
        return 0
    elif price > 100:
        return 0
    elif min_nights > 3:
        return 0
    elif nr_reviews < 10:
        return 0
    else:
        room_type_score = room_type_scores[room_type]
        prize_score = (100 - price) / 100
        review_score = 1 if nr_reviews > 50 else 0.5
        return room_type_score * prize_score * review_score

# %%
# %%timeit
listings['score'] = listings.apply(lambda row: room_score(row['availability_365'], row['price'], row['minimum_nights'], row['number_of_reviews'], row['room_type']), axis=1)
# Out:
# 217 ms ± 1.09 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
listings.sort_values('score', ascending=False)
# Out:
#       listing_id                                               name  \
# 3342     1129012                Sunny apartment no.2 in Berlin city
# 2241    22154155                    Tiny House in Berlin-Weissensee
# 4359      323260                Apartment in Berlin for 1-3 persons
# 3812    18561176                 Cozy Room in comfortable 80qm flat
# 3681    18069548           Vacation Rental at Charlotte's in Berlin
# 1834    12281381    Ideal Room for Couples Close to the City Center
# 4412    10941636                Family-friendly + near to the party
# 2743    11383656                   Cozy studio in Prenzlauer Berg 2
# 794     11381321                     Cozy studio in Prenzlauer Berg
# 1907    17688227      primeflats - City Apartment Prenzlauer Berg 7
# 3981    18941266         Bed and Coffee at the White Lake in Berlin
# 2214     2682379                Schnell nach Berlin/S-Grünbergallee
# 569      4160025                    near by TXL - ruhig & gemütlich
# 229     12905856  Süßes&helles Zimmer in Berlin-Mitte (U-Bahn Nähe)
# 3158    23091571                      STYLISH LOW COST BERLIN MITTE
# 812       883847             Maximilian´s Apartment for friends :-)
# 3308    13648211                                       CHIC & BASIC
# 3398    19382941         Modern Penthouse (2 rooms, 62 m², 4 pers.)
# 2783      564821                Nice 2 Rooms Flat "Prenzlauer Berg"
# 3817     4805605                 Room in Lichtenberg-Friederichsain
# 4047     1274386                   Wonderful home sightseeing Spree
# 4098     6691656  Room 40qm + 74qm share f 6-8 pers. southwestce...
# 2608    18364724               Zimmer in Berlin Mitte. Ladies only.
# 3306     1236282  Cozy room top location in hip & creative Neukölln
# 1621    23839778  Amazing room near central station #modern #wel...
# 1487      187206                                          cozy room
# 2488     4062245                       *cozy, quiet & central room*
# 875     16922804  Big, Bright and good located Room in Berlin City!
# 2894    15560206              Cozy sunny room in Neukölln/Kreuzberg
# 1604    11099159                Clean Room w/ own Bathroom, Centrum
# ...          ...                                                ...
# 1675    29006479                 Shared apartment in Charlottenburg
# 1646  Entire home/apt     50               2                  1  2018-08-21
# 1647     Private room     35               2                 21  2018-05-14
# 1648     Private room     25              14                  2  2018-10-07
# 1649  Entire home/apt     36               2                 41  2018-05-20
# 1651     Private room     35               2                  0         NaN
# 1652  Entire home/apt    104               3                129  2018-10-22
# 1654  Entire home/apt     47              14                  1  2014-08-15
# 1655     Private room     23               4                 74  2018-10-23
# 1656     Private room     32               2                 52  2018-03-30
# 1657  Entire home/apt     45               4                 17  2018-08-20
# 1658  Entire home/apt     81               3                  0         NaN
# 1659  Entire home/apt     44               6                  5  2018-10-31
# 1660  Entire home/apt     87               9                  3  2017-08-20
# 1661  Entire home/apt    140               2                  5  2018-08-04
# 1662     Private room     34               2                  2  2018-08-27
# 1663     Private room    115               3                  9  2017-05-02
# 1664  Entire home/apt     27               4                  7  2017-05-29
# 1665     Private room     60               3                  3  2016-07-04
# 1667  Entire home/apt     50               2                  0         NaN
# 1668     Private room     20              10                  9  2018-02-20
# 1669  Entire home/apt     99               2                  2  2015-09-15
# 1670     Private room     25               2                  3  2016-02-17
# 1671  Entire home/apt     80               7                  6  2018-09-25
# 1672  Entire home/apt     55               3                  4  2018-10-22
# 2255     Private room     50               2                  1  2017-09-04
#
#       reviews_per_month  calculated_host_listings_count  availability_365  \
# 3342               2.91                               2                73
# 2241               7.74                               1               205
# 4359               2.56                              11               248
# 3812               4.60                               3                16
# 3681               2.89                               1                 1
# 1834               5.04                               2                58
# 4412               3.76                               1                10
# 2743               3.97                               2               121
# 794                3.75                               2               136
# 1907               3.14                              45               121
# 3981               3.33                               1                39
# 2214               2.38                               4               195
# 569                1.08                               1                48
# 229                8.25                               1                33
# 3158               7.87                               4               106
# 812                1.04                               1               294
# 3308               1.88                               5               280
# 3398               7.31                               2               347
# 2783               1.89                               2               297
# 3817               1.86                               2                37
# 4047               2.01                               3                92
# 4098               2.44                               4               334
# 2608               6.34                               1               254
# 3306               2.67                               2                63
# 1621               7.13                               2                78
# 1487               2.63                               1               322
# 2488               1.04                               1                40
# 875                3.11                               1                10
# 2894               2.38                               2                86
# 1604               6.17                               7               260
# ...                 ...                             ...               ...
# 1675               1.00                               1                67
# 1673               1.50                               1               324
# 1643               0.25                               1                 0
# 1644               0.17                               1                 0
# 1645               2.69                               1               207
# 1646               0.38                               2                83
# 1647               2.16                               1                 0
# 1648               0.73                               2                32
# 1649               2.13                               1                 0
# 1651                NaN                               1                 0
# 1652               3.14                               2               218
# 1654               0.02                               1                 0
# 1655               1.90                               3                84
# 1656               3.88                               1                 0
# 1657               0.36                               1               165
# 1658                NaN                               1                 0
# 1659               1.65                               1                17
# 1660               0.08                               1               304
# 1661               1.18                               1                 0
# 1662               0.52                               1                33
# 1663               0.19                               1               284
# 1664               0.24                               2                 0
# 1665               0.07                               5               129
# 1667                NaN                               1                94
# 1668               0.28                               1                 0
# 1669               0.05                               1                 0
# 1670               0.09                               1                 0
# 1671               0.77                               1                 0
# 1672               3.16                               5               287
# 2255               0.07                               1                 0
#
#       score  room_type_score  prize_score  review_score
# 3342  0.820              1.0         0.82           1.0
# 2241  0.650              1.0         0.65           1.0
# 4359  0.640              1.0         0.64           1.0
# 3812  0.630              0.7         0.90           1.0
# 3681  0.620              1.0         0.62           1.0
# 1834  0.602              0.7         0.86           1.0
# 4412  0.600              1.0         0.60           1.0
# 2743  0.600              1.0         0.60           1.0
# 794   0.600              1.0         0.60           1.0
# 1907  0.580              1.0         0.58           1.0
# 3981  0.560              0.7         0.80           1.0
# 2214  0.560              0.7         0.80           1.0
# 569   0.560              0.7         0.80           1.0
# 229   0.553              0.7         0.79           1.0
# 3158  0.550              1.0         0.55           1.0
# 812   0.550              1.0         0.55           1.0
# 3308  0.550              1.0         0.55           1.0
# 3398  0.550              1.0         0.55           1.0
# 2783  0.540              1.0         0.54           1.0
# 3817  0.539              0.7         0.77           1.0
# 4047  0.539              0.7         0.77           1.0
# 4098  0.532              0.7         0.76           1.0
# 2608  0.532              0.7         0.76           1.0
# 3306  0.525              0.7         0.75           1.0
# 1621  0.525              0.7         0.75           1.0
# 1487  0.525              0.7         0.75           1.0
# 2488  0.525              0.7         0.75           1.0
# 875   0.525              0.7         0.75           1.0
# 2894  0.525              0.7         0.75           1.0
# 1604  0.525              0.7         0.75           1.0
# ...     ...              ...          ...           ...
# 1675  0.000              0.7         0.85           0.5
# 1673  0.000              1.0        -0.20           1.0
# 1643  0.000              0.7         0.35           0.5
# 1644  0.000              1.0         0.45           0.5
# 1645  0.000              1.0        -0.09           0.5
# 1646  0.000              1.0         0.50           0.5
# 1647  0.000              0.7         0.65           0.5
# 1648  0.000              0.7         0.75           0.5
# 1649  0.000              1.0         0.64           0.5
# 1651  0.000              0.7         0.65           0.5
# 1652  0.000              1.0        -0.04           1.0
# 1654  0.000              1.0         0.53           0.5
# 1655  0.000              0.7         0.77           1.0
# 1656  0.000              0.7         0.68           1.0
# 1657  0.000              1.0         0.55           0.5
# 1658  0.000              1.0         0.19           0.5
# 1659  0.000              1.0         0.56           0.5
# 1660  0.000              1.0         0.13           0.5
# 1661  0.000              1.0        -0.40           0.5
# 1662  0.000              0.7         0.66           0.5
# 1663  0.000              0.7        -0.15           0.5
# 1664  0.000              1.0         0.73           0.5
# 1665  0.000              0.7         0.40           0.5
# 1667  0.000              1.0         0.50           0.5
# 1668  0.000              0.7         0.80           0.5
# 1669  0.000              1.0         0.01           0.5
# 1670  0.000              0.7         0.75           0.5
# 1671  0.000              1.0         0.20           0.5
# 1672  0.000              1.0         0.45           0.5
# 2255  0.000              0.7         0.50           0.5
#
# [4510 rows x 20 columns]

# %%
listings.groupby('room_type').count()
# Out:
#                  listing_id  name  host_id  host_name  neighbourhood_group  \
# room_type
# Entire home/apt        2175  2171     2175       2171                 2175
# Private room           2281  2278     2281       2280                 2281
# Shared room              54    54       54         54                   54
#
#                  neighbourhood  latitude  longitude  price  minimum_nights  \
# room_type
# Entire home/apt           2175      2175       2175   2175            2175
# Private room              2281      2281       2281   2281            2281
# Shared room                 54        54         54     54              54
#
#                  number_of_reviews  last_review  reviews_per_month  \
# room_type
# Entire home/apt               2175         1815               1814
# Private room                  2281         1890               1888
# Shared room                     54           40                 40
#
#                  calculated_host_listings_count  availability_365
# room_type
# Entire home/apt                            2175              2175
# Private room                               2281              2281
# Shared room                                  54                54

# %% [markdown]
# ## Indexing

# %%
blabla = 0

# %% [markdown]
# ## Memory efficiency
